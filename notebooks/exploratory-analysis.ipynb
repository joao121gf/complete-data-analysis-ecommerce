# %%
import pandas as pd
import os
from IPython.display import display

# %%
# Análise de vendas:
# Quantidade de pedidos por mês

df = pd.read_csv('../data/filtred/delayed_orders_by_category.csv')

display(df)
# Out:
#     Unnamed: 0           product_category_name  delayed_orders  total_orders  \
# 0           15                 casa_conforto_2               4            24
# 1           49       moveis_colchao_e_estofado               5            38
# 2            7                           audio              45           350
# 3           37  fashion_underwear_e_moda_praia              15           121
# 4           46                 livros_tecnicos              28           260
# ..         ...                             ...             ...           ...
# 63          18                    climatizacao              10           253
# 64          44               livros_importados               2            53
# 65          40                 fraldas_higiene               1            27
# 66          39                          flores               1            29
# 67           5               artigos_de_festas               1            39
#
#     delay_percentage
# 0          16.666667
# ...
